# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
food_df = pd.read_csv(r"C:\Users\Admin\Downloads\HDSC-Introduction-to-Python-for-machine-learning-master\FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = "latin-1")

# %%
food_df.head(10)
# Out:
#    Area Code     Area  Item Code              Item  Element Code  \
# 0          4  Algeria       2501        Population           511
# 1          4  Algeria       2501        Population          5301
# 2          4  Algeria       2901       Grand Total           664
# 3          4  Algeria       2901       Grand Total           674
# 4          4  Algeria       2901       Grand Total           684
# 5          4  Algeria       2903  Vegetal Products           664
# 6          4  Algeria       2903  Vegetal Products           674
# 7          4  Algeria       2903  Vegetal Products           684
# 8          4  Algeria       2941   Animal Products           664
# 9          4  Algeria       2941   Animal Products           674
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# ...

# %% [markdown]
# Question 1

# %%
# checking the number of rows and columns in the dataset
food_df.shape
# Out:
# (60943, 12)

# %% [markdown]
# Question 2
# Creating a pandas DataFrame

# %%
#given
lst = [[35,'Portugal',94],[33,'Argentina',93],[30,'Brazil'92]]
col = ['Age','Nationality','Overall'] #create a DataFrame

pd.DataFrame(lst, columns=col, index=1)
# Out:
#   Input In [90]
#     lst = [[35,'Portugal',94],[33,'Argentina',93],[30,'Brazil'92]]
#                                                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# Question 3
# What is the total number and percentage of missing data in 2014

# %%
#total number of missing values in the dataset
food_df.isna().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
1589/60943*100
# Out:
# 2.6073544131401474

# %% [markdown]
# Question 4
# Selecting elements in a numpy array

# %%
array = ([[94,89,63],[93,92,48],[92,94,56]])
array
array[:2,1:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Admin\Downloads\HDSC-Introduction-to-Python-for-machine-learning-master\Assigment1.ipynb Cell 12 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Downloads/HDSC-Introduction-to-Python-for-machine-learning-master/Assigment1.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> array = ([[94,89,63],[93,92,48],[92,94,56]])
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Downloads/HDSC-Introduction-to-Python-for-machine-learning-master/Assigment1.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> array
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Downloads/HDSC-Introduction-to-Python-for-machine-learning-master/Assigment1.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> array[:2,1:]
#
# TypeError: list indices must be integers or slices, not tuple

# %% [markdown]
# Question 5 and 6:
# Performing a groupby operation on 'Area' to determine which area had the 7th lowest and highest sum in 2017

# %%
food_df.groupby('Area')[['Y2017','Area']].sum()
# Out:
#                                   Y2017
# Area
# Algeria                       325644.27
# Angola                        229159.57
# Benin                         124771.22
# Botswana                       22101.30
# Burkina Faso                  101855.07
# Cabo Verde                     14650.74
# Cameroon                      232030.43
# Central African Republic       29937.00
# Chad                           71594.68
# Comoros                           59.84
# Congo                          41181.68
# Côte d'Ivoire                 224599.01
# Djibouti                       22729.91
# Egypt                         866379.92
# Eswatini                       54343.33
# Ethiopia                      448683.76
# Ethiopia PDR                       0.00
# Gabon                          27979.64
# Gambia                         23154.18
# Ghana                         337599.06
# Guinea                         98138.87
# Guinea-Bissau                  19102.77
# ...

# %%
data2017data = food_df[['Area', 'Y2017']].groupby('Area').sum()

# %%
data2017data['Y2017'].sort_values()
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %% [markdown]
# Question 7:
# Total number of unique countries in the dataset

# %%
food_df['Area'].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "Côte d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo', 'Tunisia',
#        'Uganda', 'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
food_df['Area'].nunique()
# Out:
# 49

# %% [markdown]
# Question 8:
# Groupby operation on "Element" to determine the sum of processing in 2017

# %%
food_df.groupby('Element')['Y2017'].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
food_df.groupby('Element')['Area','Y2015'].sum()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_2444\4106389449.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   food_df.groupby('Element')['Area','Y2015'].sum()
#                                              Y2015
# Element
# Domestic supply quantity                2021493.55
# Export Quantity                          157614.47
# Fat supply quantity (g/capita/day)        10235.74
# Feed                                     225050.22
# Food                                    1232361.10
# Food supply (kcal/capita/day)            453383.00
# Food supply quantity (kg/capita/yr)       49345.13
# Import Quantity                          267018.46
# Losses                                   155439.00
# Other uses (non-food)                     66254.41
# Processing                               287929.00
# Production                              1947019.39
# Protein supply quantity (g/capita/day)    11833.95
# ...

# %% [markdown]
# Question 15:
# Perform a groupby sum aggregation on 'Item'

# %%
food_df.groupby('Item')['Y2015','Y2018'].sum()
# Out:
# C:\Program Files\KMSpico\temp\ipykernel_2444\1512413843.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   food_df.groupby('Item')['Y2015','Y2018'].sum()
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %% [markdown]
# Question 17:
# Mean and std deviation across the whole dataset

# %%
food_df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %% [markdown]
# Question 19:
# Determine the type of error that would be output from the code below.

# %%
my_tuppy = (1,2,5,8)
my_tuppy[2] =6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Admin\Downloads\HDSC-Introduction-to-Python-for-machine-learning-master\Assigment1.ipynb Cell 27 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Downloads/HDSC-Introduction-to-Python-for-machine-learning-master/Assigment1.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> my_tuppy = (1,2,5,8)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Downloads/HDSC-Introduction-to-Python-for-machine-learning-master/Assigment1.ipynb#X46sZmlsZQ%3D%3D?line=1'>2</a> my_tuppy[2] =6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Question 20:
# What year has the highest sum of stock variation

# %%
food_df.groupby(food_df['Element'] == 'Stock Variation').sum()
# Out:
#          Area Code  Item Code  Element Code       Y2014       Y2015  \
# Element
# False      7610981  152435083     211024093  7906336.30  7997429.24
# True        571566   11329527      21464704    58749.83    34910.99
#
#               Y2016       Y2017       Y2018
# Element
# False    8079332.53  8321412.28  8534052.05
# True       33140.12    54316.91    20577.91
